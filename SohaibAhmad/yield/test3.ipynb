# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
sns.pairplot(iris, hue = 'species')

# %%
sns.scatterplot(x = "sepal_length", y = 'sepal_width', hue = 'species', data = iris)

# %%
sns.jointplot(x = 'sepal_length', y = 'sepal_width', data = iris, kind = 'scatter')

# %%
sns.jointplot(x = 'sepal_length', y = 'sepal_width', data = iris, kind = 'kde')

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
x, y, z, c = iris['sepal_length'], iris['sepal_width'], iris['petal_length'], iris['petal_width']

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (15,8))
ax = fig.add_subplot(111, projection = '3d')

img = ax.scatter(x, y, z, c = c, cmap = plt.hot())

plt.colorbar(img)
plt.show()

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
fig = plt.figure(figsize = (15,8))
ax = fig.add_subplot(111, projection = '3d')

img = ax.scatter(x, y, z, c = c, cmap = plt.get_cmap("PiYG"))

plt.colorbar(img)

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
x1, y1, z1, c1 = iris['sepal_length'], iris['sepal_width'], iris['petal_length'], iris['petal_width']
x2, y2, z2, c2 = iris['sepal_width'], iris['petal_width'], iris['petal_width'], iris['sepal_length']
x3, y3, z3, c3 = iris['petal_length'], iris['petal_width'], iris['sepal_length'], iris['sepal_width']
x4, y4, z4, c4 = iris['petal_width'], iris['sepal_length'], iris['sepal_width'], iris['petal_length']

# %%
fig = plt.figure(figsize = (15,7))
ax = fig.add_subplot(111, projection = '3d')

img1 = ax.scatter(x1, y1, z1, c = c1, cmap = plt.get_cmap("PiYG"))
img2 = ax.scatter(x2, y2, z2, c = c2, cmap = plt.get_cmap("BrBG"))
img3 = ax.scatter(x3, y3, z3, c = c3, cmap = plt.get_cmap("PuOr"))
#img4 = ax.scatter(x4, y4, z4, c = c4, cmap = plt.get_cmap("RdGY"))

plt.colorbar(img1, img2, img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f6222829abed> in <module>
#       7 #img4 = ax.scatter(x4, y4, z4, c = c4, cmap = plt.get_cmap("RdGY"))
#       8
# ----> 9 plt.colorbar(img1, img2, img3)
#      10 plt.show()
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2007     if ax is None:
#    2008         ax = gca()
# -> 2009     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2010     return ret
#    2011 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2236                              'panchor']
#    2237         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# ...
